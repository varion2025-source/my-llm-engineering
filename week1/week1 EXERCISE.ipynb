# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-5-nano'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# constants

#MODEL_GPT = 'gpt-5-nano'
#MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
link_system_prompt = """
You are an expert in coding.
You will provided with a question.
You are able to explain the code and provide possible resources to futher study
"""

# %%
def get_user_prompt(question_code):
    user_prompt = f"""
Here is the code question {question_code} -
Please provide a exaplaination
"""   
    return user_prompt

# %%
def answer_code_question(question_code):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_user_prompt(question_code)}
        ],       
    )
    result = response.choices[0].message.content    
    return result

# %%
print(answer_code_question('question_code'))
# Out:
# I don’t see the code snippet yet. Please paste the code (or the exact question) so I can tailor an explanation.
#
# What to include or specify to get a good explanation:
# - The programming language used
# - The full code or problem statement (paste as-is)
# - What you want explained: high-level idea, step-by-step walkthrough, time/space complexity, correctness, edge cases, debugging tips, or improvements
# - Any specific parts you’re stuck on or error messages you see
# - A small reproducible example (inputs/outputs) if you have one
#
# How I’ll explain it once I have the code:
# - High-level overview: what problem is being solved and the approach
# - Line-by-line walk-through: what each part does and why
# - Correctness: why the algorithm works, with invariants if applicable
# - Complexity analysis: time and space complexities
# - Edge cases and potential bugs
# - Suggested tests and possible refactors or alternative approaches
# - Short debugging tips if something goes wrong
#
# ...

# %%
# Get Llama 3.2 to answer
print(answer_code_question(question))
# Out:
# This code is Python and is intended to be used inside a generator function (because it uses yield from). It yields unique, non-empty author values from a collection of books.
#
# What it does, step by step:
# - books is assumed to be an iterable of dictionaries, each representing a book.
# - The set comprehension {book.get("author") for book in books if book.get("author")} does the following:
#   - For each book in books, it calls book.get("author") to retrieve the author value (the key "author").
#   - The if book.get("author") part filters out any falsy values (None, empty string, 0, etc.). So only truthy author values are kept.
#   - The resulting author values are collected into a set, which removes duplicates.
# - yield from <set> then yields each element of that set to the caller, one by one.
#
# Key points:
# - It returns unique authors (thanks to the set) and ignores books that don’t have a usable author value.
# ...
